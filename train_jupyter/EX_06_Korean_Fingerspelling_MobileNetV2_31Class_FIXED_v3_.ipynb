# %% [markdown]
# # 한글 지문자 31종 MobileNetV2 학습
#
# 기존 `EX_06_RPS_MobileNetV2_Augmentation.ipynb`의 흐름을 바탕으로 수정한 버전입니다.
#
# - 데이터 폴더에서 클래스 이름 자동 인식
# - 클래스별 `train 70% / validation 20% / test 10%` 자동 분할
# - MobileNetV2 전이학습
# - 최고 validation 성능 모델 저장
# - test 데이터로 최종 성능 평가
# - 클래스 이름 JSON 저장
# - ONNX 변환 및 다운로드
#
# 데이터셋은 아래처럼 **클래스 폴더만 한 번 정리**하면 됩니다.
#
# ```text
# dataset/
# ├── ㄱ/
# │   ├── image_0000.png
# │   └── ...
# ├── ㄴ/
# ├── ㄷ/
# ├── ...
# └── ㅢ/
# ```

# %% [markdown]
# ## 1. 라이브러리 불러오기

# %%
import os
import json
import glob
import random
from pathlib import Path

import cv2
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.font_manager as fm
import tensorflow as tf

from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    confusion_matrix,
    classification_report,
    ConfusionMatrixDisplay,
)

print("NumPy Version      :", np.__version__)
print("TensorFlow Version :", tf.__version__)
print("OpenCV Version     :", cv2.__version__)

SEED = 123
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)
# Out:
# NumPy Version      : 2.0.2
# TensorFlow Version : 2.20.0
# OpenCV Version     : 4.13.0

# %% [markdown]
# ## 1-1. Colab 한글 폰트 설정
#
# 예측 결과와 Confusion Matrix에서 `ㄱ`, `ㄴ`, `ㅏ` 등이 네모로 깨지지 않도록
# 나눔고딕 폰트를 설치하고 적용합니다.

# %%
# Colab 한글 폰트 설치
# !apt-get -qq update
# !apt-get -qq install -y fonts-nanum > /dev/null

import os
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

font_path = "/usr/share/fonts/truetype/nanum/NanumGothic.ttf"

if not os.path.exists(font_path):
    raise FileNotFoundError(
        f"한글 폰트를 찾지 못했습니다: {font_path}"
    )

# Matplotlib에 폰트 파일 직접 등록
fm.fontManager.addfont(font_path)

# 파일 경로를 이용해 폰트 객체 생성
korean_font = fm.FontProperties(
    fname=font_path
)

font_name = korean_font.get_name()

# 기존에 잘못 등록된 전역 폰트 설정 초기화
mpl.rcParams.update(
    mpl.rcParamsDefault
)

# 한글 그래프에서 마이너스 기호 깨짐 방지
mpl.rcParams["axes.unicode_minus"] = False

print("적용된 한글 폰트:", font_name)

# 한글 출력 확인
fig, ax = plt.subplots(
    figsize=(8, 2)
)

ax.set_title(
    "한글 폰트 확인: ㄱ ㄴ ㄷ ㄹ ㅏ ㅑ ㅓ ㅢ",
    fontproperties=korean_font,
    fontsize=16
)

ax.axis("off")
plt.show()
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# 적용된 한글 폰트: NanumGothic

# %% [markdown]
# ## 2. Google Drive 연결

# %%
try:
    from google.colab import drive
    drive.mount('/content/drive')
    print('Google Drive mounted.')
    COLAB = True
except Exception as e:
    print('Local environment:', e)
    COLAB = False
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Google Drive mounted.

# %% [markdown]
# ## 3. 데이터셋 ZIP 압축 해제 및 경로 설정
#
# 아래 `DATASET_ZIP` 경로를 실제 ZIP 파일 위치에 맞게 수정하세요.
#
# ZIP 내부 또는 압축 해제 후 폴더 구조는 다음 중 하나면 됩니다.
#
# ```text
# dataset.zip
# └── dataset/
#     ├── ㄱ/
#     ├── ㄴ/
#     └── ...
# ```
#
# 또는 ZIP 최상위에 바로 클래스 폴더가 있어도 됩니다.

# %%
# ===== 사용자가 수정할 부분 =====
DATASET_ZIP = "/content/drive/MyDrive/ai/files/DataSet_hand_224_png.zip"
EXTRACT_ROOT = "/content/korean_fingerspelling_data"
# ================================

if COLAB:
    # !rm -rf "$EXTRACT_ROOT"
    # !mkdir -p "$EXTRACT_ROOT"
    # !unzip -q -o "$DATASET_ZIP" -d "$EXTRACT_ROOT"

print("압축 해제 위치:", EXTRACT_ROOT)
# Out:
# 압축 해제 위치: /content/korean_fingerspelling_data

# %% [markdown]
# ## 4. 실제 클래스 폴더 자동 탐색

# %%
IMAGE_EXTENSIONS = {".png", ".jpg", ".jpeg", ".bmp", ".webp"}

KOREAN_CLASS_NAMES = [
    "ㄱ", "ㄴ", "ㄷ", "ㄹ", "ㅁ", "ㅂ", "ㅅ",
    "ㅇ", "ㅈ", "ㅊ", "ㅋ", "ㅌ", "ㅍ", "ㅎ",
    "ㅏ", "ㅑ", "ㅓ", "ㅕ", "ㅗ", "ㅛ", "ㅜ",
    "ㅠ", "ㅡ", "ㅣ", "ㅐ", "ㅒ", "ㅔ", "ㅖ",
    "ㅚ", "ㅟ", "ㅢ"
]

def contains_images(folder):
    folder = Path(folder)

    return any(
        p.is_file() and p.suffix.lower() in IMAGE_EXTENSIONS
        for p in folder.rglob("*")
    )

def find_dataset_root(extract_root):
    extract_root = Path(extract_root)

    direct_class_dirs = [
        p for p in extract_root.iterdir()
        if p.is_dir() and contains_images(p)
    ]

    if len(direct_class_dirs) >= 2:
        return extract_root

    candidates = []

    for folder in extract_root.rglob("*"):
        if not folder.is_dir():
            continue

        child_dirs = [
            p for p in folder.iterdir()
            if p.is_dir() and contains_images(p)
        ]

        if len(child_dirs) >= 2:
            candidates.append((len(child_dirs), folder))

    if not candidates:
        raise FileNotFoundError(
            "클래스 폴더를 찾지 못했습니다. "
            "dataset/ㄱ/*.png 형태인지 확인하세요."
        )

    candidates.sort(key=lambda item: item[0], reverse=True)
    return candidates[0][1]

def class_sort_key(path):
    if path.name.isdigit():
        return (0, int(path.name))

    if path.name in KOREAN_CLASS_NAMES:
        return (1, KOREAN_CLASS_NAMES.index(path.name))

    return (2, path.name)

DATASET_ROOT = find_dataset_root(EXTRACT_ROOT)

class_dirs = sorted(
    [
        p for p in DATASET_ROOT.iterdir()
        if p.is_dir() and contains_images(p)
    ],
    key=class_sort_key
)

num_classes = len(class_dirs)

all_numeric_folders = all(
    p.name.isdigit()
    for p in class_dirs
)

if all_numeric_folders and num_classes == len(KOREAN_CLASS_NAMES):
    class_names = KOREAN_CLASS_NAMES.copy()
else:
    class_names = [p.name for p in class_dirs]

print("데이터셋 위치:", DATASET_ROOT)
print("클래스 수:", num_classes)
print("폴더 순서:", [p.name for p in class_dirs])
print("표시할 클래스:", class_names)

for index, name in enumerate(class_names):
    print(f"{index:2d} -> {name}")

if num_classes != 31:
    print(
        f"주의: 예상 클래스 수는 31개이지만 "
        f"현재 {num_classes}개가 감지되었습니다."
    )
# Out:
# 데이터셋 위치: /content/korean_fingerspelling_data
# 클래스 수: 31
# 폴더 순서: ['ㄱ', 'ㄴ', 'ㄷ', 'ㄹ', 'ㅁ', 'ㅂ', 'ㅅ', 'ㅇ', 'ㅈ', 'ㅊ', 'ㅋ', 'ㅌ', 'ㅍ', 'ㅎ', 'ㅏ', 'ㅑ', 'ㅓ', 'ㅕ', 'ㅗ', 'ㅛ', 'ㅜ', 'ㅠ', 'ㅡ', 'ㅣ', 'ㅐ', 'ㅒ', 'ㅔ', 'ㅖ', 'ㅚ', 'ㅟ', 'ㅢ']
# 표시할 클래스: ['ㄱ', 'ㄴ', 'ㄷ', 'ㄹ', 'ㅁ', 'ㅂ', 'ㅅ', 'ㅇ', 'ㅈ', 'ㅊ', 'ㅋ', 'ㅌ', 'ㅍ', 'ㅎ', 'ㅏ', 'ㅑ', 'ㅓ', 'ㅕ', 'ㅗ', 'ㅛ', 'ㅜ', 'ㅠ', 'ㅡ', 'ㅣ', 'ㅐ', 'ㅒ', 'ㅔ', 'ㅖ', 'ㅚ', 'ㅟ', 'ㅢ']
#  0 -> ㄱ
#  1 -> ㄴ
#  2 -> ㄷ
#  3 -> ㄹ
#  4 -> ㅁ
#  5 -> ㅂ
#  6 -> ㅅ
#  7 -> ㅇ
#  8 -> ㅈ
#  9 -> ㅊ
# 10 -> ㅋ
# 11 -> ㅌ
# 12 -> ㅍ
# 13 -> ㅎ
# 14 -> ㅏ
# 15 -> ㅑ
# 16 -> ㅓ
# 17 -> ㅕ
# 18 -> ㅗ
# 19 -> ㅛ
# 20 -> ㅜ
# 21 -> ㅠ
# 22 -> ㅡ
# 23 -> ㅣ
# 24 -> ㅐ
# 25 -> ㅒ
# 26 -> ㅔ
# 27 -> ㅖ
# 28 -> ㅚ
# 29 -> ㅟ
# 30 -> ㅢ

# %% [markdown]
# ## 5. 이미지 읽기 및 클래스별 70:20:10 자동 분할
#
# 원본 이미지는 그대로 두고, 학습 시점에 `224×224`로 resize합니다.
#
# 각 클래스가 100장이면 자동으로:
#
# - train: 70장
# - validation: 20장
# - test: 10장
#
# 으로 나뉩니다.

# %%
IMG_SIZE = 224

train_data_list = []
train_label_list = []

val_data_list = []
val_label_list = []

test_data_list = []
test_label_list = []

split_summary = []

for class_index, class_dir in enumerate(class_dirs):
    image_files = sorted([
        p for p in class_dir.rglob("*")
        if p.is_file() and p.suffix.lower() in IMAGE_EXTENSIONS
    ])

    images = []

    for image_path in image_files:
        image = cv2.imread(str(image_path), cv2.IMREAD_COLOR)

        if image is None:
            print("읽기 실패:", image_path)
            continue

        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        image = cv2.resize(
            image,
            (IMG_SIZE, IMG_SIZE),
            interpolation=cv2.INTER_AREA
        )

        images.append(image)

    images = np.asarray(images, dtype=np.uint8)
    labels = np.full(len(images), class_index, dtype=np.int32)

    if len(images) < 10:
        raise ValueError(
            f"{class_dir.name} 클래스의 이미지가 너무 적습니다: {len(images)}장"
        )

    # 1차: train 70%, 나머지 30%
    x_train, x_temp, y_train, y_temp = train_test_split(
        images,
        labels,
        test_size=0.30,
        random_state=SEED,
        shuffle=True
    )

    # 2차: 전체 기준 val 20%, test 10%
    # temp 30% 중 2/3는 val, 1/3은 test
    x_val, x_test, y_val, y_test = train_test_split(
        x_temp,
        y_temp,
        test_size=1/3,
        random_state=SEED,
        shuffle=True
    )

    train_data_list.append(x_train)
    train_label_list.append(y_train)

    val_data_list.append(x_val)
    val_label_list.append(y_val)

    test_data_list.append(x_test)
    test_label_list.append(y_test)

    split_summary.append({
        "class": class_dir.name,
        "total": len(images),
        "train": len(x_train),
        "val": len(x_val),
        "test": len(x_test)
    })


train_data = np.concatenate(train_data_list, axis=0)
train_labels = np.concatenate(train_label_list, axis=0)

val_data = np.concatenate(val_data_list, axis=0)
val_labels = np.concatenate(val_label_list, axis=0)

test_data = np.concatenate(test_data_list, axis=0)
test_labels = np.concatenate(test_label_list, axis=0)

# 전체 데이터 순서를 한 번 더 섞음
def shuffle_dataset(data, labels, seed):
    rng = np.random.default_rng(seed)
    indices = rng.permutation(len(data))
    return data[indices], labels[indices]

train_data, train_labels = shuffle_dataset(train_data, train_labels, SEED)
val_data, val_labels = shuffle_dataset(val_data, val_labels, SEED)
test_data, test_labels = shuffle_dataset(test_data, test_labels, SEED)

print("train:", train_data.shape, train_labels.shape)
print("val  :", val_data.shape, val_labels.shape)
print("test :", test_data.shape, test_labels.shape)

for item in split_summary:
    print(
        f"{item['class']}: "
        f"total={item['total']}, "
        f"train={item['train']}, "
        f"val={item['val']}, "
        f"test={item['test']}"
    )
# Out:
# train: (8243, 224, 224, 3) (8243,)
# val  : (2358, 224, 224, 3) (2358,)
# test : (1196, 224, 224, 3) (1196,)
# ㄱ: total=376, train=263, val=75, test=38
# ㄴ: total=377, train=263, val=76, test=38
# ㄷ: total=378, train=264, val=76, test=38
# ㄹ: total=378, train=264, val=76, test=38
# ㅁ: total=380, train=266, val=76, test=38
# ㅂ: total=377, train=263, val=76, test=38
# ㅅ: total=362, train=253, val=72, test=37
# ㅇ: total=378, train=264, val=76, test=38
# ㅈ: total=377, train=263, val=76, test=38
# ㅊ: total=381, train=266, val=76, test=39
# ㅋ: total=379, train=265, val=76, test=38
# ㅌ: total=376, train=263, val=75, test=38
# ㅍ: total=381, train=266, val=76, test=39
# ㅎ: total=380, train=266, val=76, test=38
# ㅏ: total=384, train=268, val=77, test=39
# ㅑ: total=382, train=267, val=76, test=39
# ㅓ: total=381, train=266, val=76, test=39
# ㅕ: total=381, train=266, val=76, test=39
# ㅗ: total=391, train=273, val=78, test=40
# ㅛ: total=380, train=266, val=76, test=38
# ㅜ: total=382, train=267, val=76, test=39
# ㅠ: total=386, train=270, val=77, test=39
# ㅡ: total=383, train=268, val=76, test=39
# ㅣ: total=394, train=275, val=79, test=40
# ㅐ: total=381, train=266, val=76, test=39
# ㅒ: total=383, train=268, val=76, test=39
# ㅔ: total=380, train=266, val=76, test=38
# ㅖ: total=381, train=266, val=76, test=39
# ㅚ: total=386, train=270, val=77, test=39
# ㅟ: total=381, train=266, val=76, test=39
# ㅢ: total=381, train=266, val=76, test=39

# %% [markdown]
# ## 6. 클래스 이름 저장

# %%
CLASS_NAMES_FILE = "korean_fingerspelling_class_names.json"

with open(CLASS_NAMES_FILE, "w", encoding="utf-8") as f:
    json.dump(
        class_names,
        f,
        ensure_ascii=False,
        indent=2
    )

print("저장 완료:", CLASS_NAMES_FILE)
# Out:
# 저장 완료: korean_fingerspelling_class_names.json

# %% [markdown]
# ## 7. 데이터 샘플 확인

# %%
plt.figure(figsize=(15, 8))

sample_count = min(20, len(train_data))
indices = np.random.choice(
    len(train_data),
    sample_count,
    replace=False
)

for plot_index, data_index in enumerate(indices):
    plt.subplot(4, 5, plot_index + 1)
    plt.imshow(train_data[data_index])
    plt.title(class_names[int(train_labels[data_index])])
    plt.axis("off")

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_9850/3423214652.py:16: UserWarning: Glyph 12631 (\N{HANGUL LETTER O}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_9850/3423214652.py:16: UserWarning: Glyph 12627 (\N{HANGUL LETTER EO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_9850/3423214652.py:16: UserWarning: Glyph 12596 (\N{HANGUL LETTER NIEUN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_9850/3423214652.py:16: UserWarning: Glyph 12642 (\N{HANGUL LETTER YI}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_9850/3423214652.py:16: UserWarning: Glyph 12625 (\N{HANGUL LETTER YA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_9850/3423214652.py:16: UserWarning: Glyph 12622 (\N{HANGUL LETTER HIEUH}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_9850/3423214652.py:16: UserWarning: Glyph 12618 (\N{HANGUL LETTER CHIEUCH}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_9850/3423214652.py:16: UserWarning: Glyph 12620 (\N{HANGUL LETTER THIEUTH}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_9850/3423214652.py:16: UserWarning: Glyph 12599 (\N{HANGUL LETTER TIKEUT}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_9850/3423214652.py:16: UserWarning: Glyph 12636 (\N{HANGUL LETTER U}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_9850/3423214652.py:16: UserWarning: Glyph 12615 (\N{HANGUL LETTER IEUNG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_9850/3423214652.py:16: UserWarning: Glyph 12610 (\N{HANGUL LETTER PIEUP}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_9850/3423214652.py:16: UserWarning: Glyph 12609 (\N{HANGUL LETTER MIEUM}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_9850/3423214652.py:16: UserWarning: Glyph 12628 (\N{HANGUL LETTER E}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 12631 (\N{HANGUL LETTER O}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 12627 (\N{HANGUL LETTER EO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 12596 (\N{HANGUL LETTER NIEUN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 12642 (\N{HANGUL LETTER YI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 12625 (\N{HANGUL LETTER YA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 12622 (\N{HANGUL LETTER HIEUH}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 12618 (\N{HANGUL LETTER CHIEUCH}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 12620 (\N{HANGUL LETTER THIEUTH}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 12599 (\N{HANGUL LETTER TIKEUT}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 12636 (\N{HANGUL LETTER U}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 12615 (\N{HANGUL LETTER IEUNG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 12610 (\N{HANGUL LETTER PIEUP}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 12609 (\N{HANGUL LETTER MIEUM}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 12628 (\N{HANGUL LETTER E}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## 8. 학습 데이터 증강
#
# 지문자 방향을 보존하기 위해 좌우 반전은 사용하지 않습니다.

# %%
img_gen_train = tf.keras.preprocessing.image.ImageDataGenerator(
    rotation_range=8,
    width_shift_range=0.08,
    height_shift_range=0.08,
    brightness_range=(0.75, 1.25),
    zoom_range=0.10,
    fill_mode="nearest"
)

train_gen = img_gen_train.flow(
    train_data,
    train_labels,
    batch_size=32,
    shuffle=True,
    seed=SEED
)

# %% [markdown]
# ## 9. MobileNetV2 모델 생성

# %%
inputs = tf.keras.Input(
    shape=(IMG_SIZE, IMG_SIZE, 3),
    name="input"
)

x = tf.keras.applications.mobilenet_v2.preprocess_input(inputs)

base_model = tf.keras.applications.MobileNetV2(
    weights="imagenet",
    include_top=False,
    input_shape=(IMG_SIZE, IMG_SIZE, 3)
)

base_model.trainable = False

x = base_model(x, training=False)
x = tf.keras.layers.GlobalAveragePooling2D()(x)
x = tf.keras.layers.Dense(128, activation="relu")(x)
x = tf.keras.layers.Dropout(0.3)(x)

outputs = tf.keras.layers.Dense(
    num_classes,
    activation="softmax",
    name="output"
)(x)

model = tf.keras.Model(inputs, outputs)

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input (InputLayer)              │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ true_divide (TrueDivide)        │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ subtract (Subtract)             │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ mobilenetv2_1.00_224            │ (None, 7, 7, 1280)     │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       163,968 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 31)             │         3,999 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,425,951 (9.25 MB)
#  Trainable params: 167,967 (656.12 KB)
#  Non-trainable params: 2,257,984 (8.61 MB)

# %% [markdown]
# ## 10. 모델 컴파일

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

# %% [markdown]
# ## 11. 학습 전 예측 확인

# %%
def show_predictions(
    title,
    data,
    labels,
    prediction_indices,
    count=10
):
    count = min(count, len(data))

    selected = np.linspace(
        0,
        len(data) - 1,
        count,
        dtype=int
    )

    rows = 2
    cols = 5

    fig, axes = plt.subplots(
        rows,
        cols,
        figsize=(18, 10)
    )

    fig.suptitle(
        title,
        fontproperties=korean_font,
        fontsize=18,
        y=0.98
    )

    axes = axes.flatten()

    for plot_index, data_index in enumerate(selected):
        ax = axes[plot_index]

        true_index = int(labels[data_index])
        pred_index = int(prediction_indices[data_index])

        true_name = class_names[true_index]
        pred_name = class_names[pred_index]

        ax.imshow(data[data_index])

        ax.set_title(
            f"정답: {true_name}\n예측: {pred_name}",
            fontproperties=korean_font,
            fontsize=12,
            pad=10
        )

        ax.axis("off")

    for index in range(count, len(axes)):
        axes[index].axis("off")

    plt.subplots_adjust(
        top=0.90,
        bottom=0.05,
        left=0.03,
        right=0.97,
        wspace=0.15,
        hspace=0.45
    )

    plt.show()


before_output = model.predict(
    val_data,
    batch_size=32
)

before_prediction = np.argmax(
    before_output,
    axis=1
)

show_predictions(
    "학습 전 예측 결과",
    val_data,
    val_labels,
    before_prediction
)
# Out:
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 35s 230ms/step

# %% [markdown]
# ## 12. 학습

# %%
SAVED_MODEL_NAME = "Korean_Fingerspelling_MobileNetV2.keras"

callbacks = [
    tf.keras.callbacks.ModelCheckpoint(
        SAVED_MODEL_NAME,
        monitor="val_accuracy",
        save_best_only=True,
        mode="max",
        verbose=1
    ),
    tf.keras.callbacks.EarlyStopping(
        monitor="val_loss",
        patience=7,
        restore_best_weights=True,
        verbose=1
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss",
        factor=0.5,
        patience=3,
        min_lr=1e-7,
        verbose=1
    )
]

history = model.fit(
    train_gen,
    epochs=30,
    callbacks=callbacks,
    validation_data=(val_data, val_labels)
)
# Out:
# Epoch 1/30
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 0s 566ms/step - accuracy: 0.0976 - loss: 3.3656
# Epoch 1: val_accuracy improved from None to 0.43130, saving model to Korean_Fingerspelling_MobileNetV2.keras
#
# Epoch 1: finished saving model to Korean_Fingerspelling_MobileNetV2.keras
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 172s 621ms/step - accuracy: 0.1623 - loss: 3.0325 - val_accuracy: 0.4313 - val_loss: 2.2604 - learning_rate: 1.0000e-04
# Epoch 2/30
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 0s 511ms/step - accuracy: 0.3524 - loss: 2.2930
# Epoch 2: val_accuracy improved from 0.43130 to 0.67812, saving model to Korean_Fingerspelling_MobileNetV2.keras
#
# Epoch 2: finished saving model to Korean_Fingerspelling_MobileNetV2.keras
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 134s 521ms/step - accuracy: 0.3961 - loss: 2.1179 - val_accuracy: 0.6781 - val_loss: 1.4785 - learning_rate: 1.0000e-04
# Epoch 3/30
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 0s 507ms/step - accuracy: 0.5200 - loss: 1.6739
# Epoch 3: val_accuracy improved from 0.67812 to 0.76336, saving model to Korean_Fingerspelling_MobileNetV2.keras
#
# Epoch 3: finished saving model to Korean_Fingerspelling_MobileNetV2.keras
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 134s 518ms/step - accuracy: 0.5474 - loss: 1.5811 - val_accuracy: 0.7634 - val_loss: 1.0821 - learning_rate: 1.0000e-04
# Epoch 4/30
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 0s 501ms/step - accuracy: 0.6101 - loss: 1.3391
# Epoch 4: val_accuracy improved from 0.76336 to 0.79856, saving model to Korean_Fingerspelling_MobileNetV2.keras
#
# Epoch 4: finished saving model to Korean_Fingerspelling_MobileNetV2.keras
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 132s 513ms/step - accuracy: 0.6232 - loss: 1.2984 - val_accuracy: 0.7986 - val_loss: 0.8692 - learning_rate: 1.0000e-04
# Epoch 5/30
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 0s 501ms/step - accuracy: 0.6840 - loss: 1.1160
# Epoch 5: val_accuracy improved from 0.79856 to 0.83503, saving model to Korean_Fingerspelling_MobileNetV2.keras
#
# Epoch 5: finished saving model to Korean_Fingerspelling_MobileNetV2.keras
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 132s 512ms/step - accuracy: 0.6887 - loss: 1.0865 - val_accuracy: 0.8350 - val_loss: 0.7315 - learning_rate: 1.0000e-04
# Epoch 6/30
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 0s 504ms/step - accuracy: 0.7209 - loss: 0.9779
# Epoch 6: val_accuracy improved from 0.83503 to 0.84902, saving model to Korean_Fingerspelling_MobileNetV2.keras
#
# Epoch 6: finished saving model to Korean_Fingerspelling_MobileNetV2.keras
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 133s 514ms/step - accuracy: 0.7280 - loss: 0.9447 - val_accuracy: 0.8490 - val_loss: 0.6334 - learning_rate: 1.0000e-04
# Epoch 7/30
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 0s 495ms/step - accuracy: 0.7655 - loss: 0.8343
# Epoch 7: val_accuracy improved from 0.84902 to 0.86514, saving model to Korean_Fingerspelling_MobileNetV2.keras
#
# Epoch 7: finished saving model to Korean_Fingerspelling_MobileNetV2.keras
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 131s 506ms/step - accuracy: 0.7619 - loss: 0.8247 - val_accuracy: 0.8651 - val_loss: 0.5591 - learning_rate: 1.0000e-04
# Epoch 8/30
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 0s 502ms/step - accuracy: 0.7689 - loss: 0.7811
# Epoch 8: val_accuracy improved from 0.86514 to 0.88126, saving model to Korean_Fingerspelling_MobileNetV2.keras
#
# Epoch 8: finished saving model to Korean_Fingerspelling_MobileNetV2.keras
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 133s 515ms/step - accuracy: 0.7839 - loss: 0.7484 - val_accuracy: 0.8813 - val_loss: 0.5022 - learning_rate: 1.0000e-04
# Epoch 9/30
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 0s 496ms/step - accuracy: 0.7971 - loss: 0.7021
# Epoch 9: val_accuracy improved from 0.88126 to 0.89101, saving model to Korean_Fingerspelling_MobileNetV2.keras
#
# Epoch 9: finished saving model to Korean_Fingerspelling_MobileNetV2.keras
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 131s 507ms/step - accuracy: 0.7983 - loss: 0.6878 - val_accuracy: 0.8910 - val_loss: 0.4514 - learning_rate: 1.0000e-04
# Epoch 10/30
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 0s 503ms/step - accuracy: 0.8133 - loss: 0.6354
# Epoch 10: val_accuracy improved from 0.89101 to 0.89398, saving model to Korean_Fingerspelling_MobileNetV2.keras
#
# Epoch 10: finished saving model to Korean_Fingerspelling_MobileNetV2.keras
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 132s 513ms/step - accuracy: 0.8143 - loss: 0.6310 - val_accuracy: 0.8940 - val_loss: 0.4220 - learning_rate: 1.0000e-04
# Epoch 11/30
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 0s 502ms/step - accuracy: 0.8316 - loss: 0.5939
# Epoch 11: val_accuracy improved from 0.89398 to 0.90246, saving model to Korean_Fingerspelling_MobileNetV2.keras
#
# Epoch 11: finished saving model to Korean_Fingerspelling_MobileNetV2.keras
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 132s 513ms/step - accuracy: 0.8291 - loss: 0.5880 - val_accuracy: 0.9025 - val_loss: 0.3905 - learning_rate: 1.0000e-04
# Epoch 12/30
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 0s 499ms/step - accuracy: 0.8463 - loss: 0.5464
# Epoch 12: val_accuracy improved from 0.90246 to 0.90797, saving model to Korean_Fingerspelling_MobileNetV2.keras
#
# Epoch 12: finished saving model to Korean_Fingerspelling_MobileNetV2.keras
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 132s 513ms/step - accuracy: 0.8429 - loss: 0.5415 - val_accuracy: 0.9080 - val_loss: 0.3629 - learning_rate: 1.0000e-04
# Epoch 13/30
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 0s 495ms/step - accuracy: 0.8540 - loss: 0.5020
# Epoch 13: val_accuracy improved from 0.90797 to 0.91221, saving model to Korean_Fingerspelling_MobileNetV2.keras
#
# Epoch 13: finished saving model to Korean_Fingerspelling_MobileNetV2.keras
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 131s 506ms/step - accuracy: 0.8549 - loss: 0.4967 - val_accuracy: 0.9122 - val_loss: 0.3367 - learning_rate: 1.0000e-04
# Epoch 14/30
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 0s 507ms/step - accuracy: 0.8668 - loss: 0.4732
# Epoch 14: val_accuracy improved from 0.91221 to 0.91773, saving model to Korean_Fingerspelling_MobileNetV2.keras
#
# Epoch 14: finished saving model to Korean_Fingerspelling_MobileNetV2.keras
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 134s 518ms/step - accuracy: 0.8622 - loss: 0.4779 - val_accuracy: 0.9177 - val_loss: 0.3246 - learning_rate: 1.0000e-04
# Epoch 15/30
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 0s 501ms/step - accuracy: 0.8716 - loss: 0.4468
# Epoch 15: val_accuracy improved from 0.91773 to 0.91985, saving model to Korean_Fingerspelling_MobileNetV2.keras
#
# Epoch 15: finished saving model to Korean_Fingerspelling_MobileNetV2.keras
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 132s 512ms/step - accuracy: 0.8679 - loss: 0.4534 - val_accuracy: 0.9198 - val_loss: 0.3126 - learning_rate: 1.0000e-04
# Epoch 16/30
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 0s 492ms/step - accuracy: 0.8773 - loss: 0.4258
# Epoch 16: val_accuracy improved from 0.91985 to 0.92366, saving model to Korean_Fingerspelling_MobileNetV2.keras
#
# Epoch 16: finished saving model to Korean_Fingerspelling_MobileNetV2.keras
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 130s 504ms/step - accuracy: 0.8743 - loss: 0.4259 - val_accuracy: 0.9237 - val_loss: 0.2922 - learning_rate: 1.0000e-04
# Epoch 17/30
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 0s 506ms/step - accuracy: 0.8863 - loss: 0.3990
# Epoch 17: val_accuracy improved from 0.92366 to 0.92791, saving model to Korean_Fingerspelling_MobileNetV2.keras
#
# Epoch 17: finished saving model to Korean_Fingerspelling_MobileNetV2.keras
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 134s 518ms/step - accuracy: 0.8797 - loss: 0.4122 - val_accuracy: 0.9279 - val_loss: 0.2767 - learning_rate: 1.0000e-04
# Epoch 18/30
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 0s 495ms/step - accuracy: 0.8918 - loss: 0.3751
# Epoch 18: val_accuracy improved from 0.92791 to 0.93427, saving model to Korean_Fingerspelling_MobileNetV2.keras
#
# Epoch 18: finished saving model to Korean_Fingerspelling_MobileNetV2.keras
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 131s 505ms/step - accuracy: 0.8907 - loss: 0.3759 - val_accuracy: 0.9343 - val_loss: 0.2622 - learning_rate: 1.0000e-04
# Epoch 19/30
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 0s 504ms/step - accuracy: 0.8963 - loss: 0.3707
# Epoch 19: val_accuracy improved from 0.93427 to 0.94148, saving model to Korean_Fingerspelling_MobileNetV2.keras
#
# Epoch 19: finished saving model to Korean_Fingerspelling_MobileNetV2.keras
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 133s 515ms/step - accuracy: 0.8923 - loss: 0.3687 - val_accuracy: 0.9415 - val_loss: 0.2513 - learning_rate: 1.0000e-04
# Epoch 20/30
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 0s 504ms/step - accuracy: 0.9071 - loss: 0.3377
# Epoch 20: val_accuracy did not improve from 0.94148
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 133s 514ms/step - accuracy: 0.9019 - loss: 0.3465 - val_accuracy: 0.9330 - val_loss: 0.2447 - learning_rate: 1.0000e-04
# Epoch 21/30
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 0s 494ms/step - accuracy: 0.8970 - loss: 0.3419
# Epoch 21: val_accuracy did not improve from 0.94148
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 130s 502ms/step - accuracy: 0.9009 - loss: 0.3349 - val_accuracy: 0.9338 - val_loss: 0.2339 - learning_rate: 1.0000e-04
# Epoch 22/30
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 0s 503ms/step - accuracy: 0.9106 - loss: 0.3246
# Epoch 22: val_accuracy did not improve from 0.94148
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 132s 512ms/step - accuracy: 0.9089 - loss: 0.3197 - val_accuracy: 0.9411 - val_loss: 0.2283 - learning_rate: 1.0000e-04
# Epoch 23/30
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 0s 506ms/step - accuracy: 0.9185 - loss: 0.2969
# Epoch 23: val_accuracy did not improve from 0.94148
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 133s 514ms/step - accuracy: 0.9137 - loss: 0.3056 - val_accuracy: 0.9394 - val_loss: 0.2196 - learning_rate: 1.0000e-04
# Epoch 24/30
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 0s 491ms/step - accuracy: 0.9151 - loss: 0.2972
# Epoch 24: val_accuracy did not improve from 0.94148
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 129s 500ms/step - accuracy: 0.9150 - loss: 0.2965 - val_accuracy: 0.9411 - val_loss: 0.2149 - learning_rate: 1.0000e-04
# Epoch 25/30
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 0s 502ms/step - accuracy: 0.9198 - loss: 0.2822
# Epoch 25: val_accuracy improved from 0.94148 to 0.94869, saving model to Korean_Fingerspelling_MobileNetV2.keras
#
# Epoch 25: finished saving model to Korean_Fingerspelling_MobileNetV2.keras
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 133s 512ms/step - accuracy: 0.9219 - loss: 0.2811 - val_accuracy: 0.9487 - val_loss: 0.2019 - learning_rate: 1.0000e-04
# Epoch 26/30
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 0s 510ms/step - accuracy: 0.9252 - loss: 0.2670
# Epoch 26: val_accuracy did not improve from 0.94869
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 134s 519ms/step - accuracy: 0.9232 - loss: 0.2681 - val_accuracy: 0.9461 - val_loss: 0.2009 - learning_rate: 1.0000e-04
# Epoch 27/30
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 0s 489ms/step - accuracy: 0.9242 - loss: 0.2658
# Epoch 27: val_accuracy improved from 0.94869 to 0.94953, saving model to Korean_Fingerspelling_MobileNetV2.keras
#
# Epoch 27: finished saving model to Korean_Fingerspelling_MobileNetV2.keras
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 129s 502ms/step - accuracy: 0.9264 - loss: 0.2620 - val_accuracy: 0.9495 - val_loss: 0.1893 - learning_rate: 1.0000e-04
# Epoch 28/30
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 0s 492ms/step - accuracy: 0.9319 - loss: 0.2460
# Epoch 28: val_accuracy did not improve from 0.94953
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 129s 501ms/step - accuracy: 0.9293 - loss: 0.2498 - val_accuracy: 0.9487 - val_loss: 0.1872 - learning_rate: 1.0000e-04
# Epoch 29/30
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 0s 504ms/step - accuracy: 0.9354 - loss: 0.2359
# Epoch 29: val_accuracy improved from 0.94953 to 0.95293, saving model to Korean_Fingerspelling_MobileNetV2.keras
#
# Epoch 29: finished saving model to Korean_Fingerspelling_MobileNetV2.keras
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 133s 515ms/step - accuracy: 0.9315 - loss: 0.2419 - val_accuracy: 0.9529 - val_loss: 0.1806 - learning_rate: 1.0000e-04
# Epoch 30/30
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 0s 499ms/step - accuracy: 0.9277 - loss: 0.2440
# Epoch 30: val_accuracy did not improve from 0.95293
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 131s 508ms/step - accuracy: 0.9283 - loss: 0.2452 - val_accuracy: 0.9495 - val_loss: 0.1802 - learning_rate: 1.0000e-04
# Restoring model weights from the end of the best epoch: 30.

# %% [markdown]
# ## 13. 학습 결과 그래프

# %%
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.title("Accuracy")
plt.plot(history.history["accuracy"], label="train_accuracy")
plt.plot(history.history["val_accuracy"], label="val_accuracy")
plt.grid(True)
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()

plt.subplot(1, 2, 2)
plt.title("Loss")
plt.plot(history.history["loss"], label="train_loss")
plt.plot(history.history["val_loss"], label="val_loss")
plt.grid(True)
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 14. 최고 성능 모델 불러오기 및 test 평가

# %%
model_best = tf.keras.models.load_model(SAVED_MODEL_NAME)

test_loss, test_accuracy = model_best.evaluate(
    test_data,
    test_labels,
    batch_size=32,
    verbose=1
)

print(f"Test loss     : {test_loss:.4f}")
print(f"Test accuracy : {test_accuracy:.4f}")
# Out:
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 24s 407ms/step - accuracy: 0.9406 - loss: 0.2129
# Test loss     : 0.2129
# Test accuracy : 0.9406

# %% [markdown]
# ## 15. 최종 예측 샘플 확인

# %%
test_output = model_best.predict(
    test_data,
    batch_size=32
)

test_prediction = np.argmax(
    test_output,
    axis=1
)

show_predictions(
    "학습 후 예측 결과",
    test_data,
    test_labels,
    test_prediction,
    count=10
)
# Out:
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 14s 224ms/step

# %% [markdown]
# ## 16. Confusion Matrix 및 클래스별 결과

# %%
from sklearn.metrics import (
    confusion_matrix,
    classification_report,
    ConfusionMatrixDisplay,
)

if "test_prediction" not in globals():
    test_output = model_best.predict(
        test_data,
        batch_size=32
    )

    test_prediction = np.argmax(
        test_output,
        axis=1
    )

cm = confusion_matrix(
    test_labels,
    test_prediction,
    labels=np.arange(num_classes)
)

fig, ax = plt.subplots(
    figsize=(20, 20)
)

disp = ConfusionMatrixDisplay(
    confusion_matrix=cm,
    display_labels=class_names
)

disp.plot(
    ax=ax,
    xticks_rotation=90,
    cmap="Blues",
    colorbar=False,
    values_format="d"
)

ax.set_title(
    "한글 지문자 Confusion Matrix",
    fontsize=20,
    fontproperties=korean_font
)

ax.set_xlabel(
    "예측한 지문자",
    fontsize=14,
    fontproperties=korean_font
)

ax.set_ylabel(
    "실제 지문자",
    fontsize=14,
    fontproperties=korean_font
)

for label in ax.get_xticklabels():
    label.set_fontproperties(korean_font)
    label.set_fontsize(10)

for label in ax.get_yticklabels():
    label.set_fontproperties(korean_font)
    label.set_fontsize(10)

plt.tight_layout()
plt.show()

print(
    classification_report(
        test_labels,
        test_prediction,
        labels=np.arange(num_classes),
        target_names=class_names,
        digits=4,
        zero_division=0
    )
)
# Out:
#               precision    recall  f1-score   support
#
#            ㄱ     0.9268    1.0000    0.9620        38
#            ㄴ     0.9722    0.9211    0.9459        38
#            ㄷ     0.8780    0.9474    0.9114        38
#            ㄹ     1.0000    0.9474    0.9730        38
#            ㅁ     0.9730    0.9474    0.9600        38
#            ㅂ     0.9737    0.9737    0.9737        38
#            ㅅ     0.8750    0.9459    0.9091        37
#            ㅇ     0.9737    0.9737    0.9737        38
#            ㅈ     0.7857    0.8684    0.8250        38
#            ㅊ     0.9118    0.7949    0.8493        39
#            ㅋ     0.9474    0.9474    0.9474        38
#            ㅌ     0.9706    0.8684    0.9167        38
#            ㅍ     1.0000    1.0000    1.0000        39
#            ㅎ     1.0000    0.9737    0.9867        38
#            ㅏ     0.9024    0.9487    0.9250        39
#            ㅑ     1.0000    0.9487    0.9737        39
#            ㅓ     0.9000    0.9231    0.9114        39
#            ㅕ     0.8947    0.8718    0.8831        39
#            ㅗ     1.0000    0.9750    0.9873        40
#            ㅛ     0.9268    1.0000    0.9620        38
#            ㅜ     0.9412    0.8205    0.8767        39
#            ㅠ     0.9250    0.9487    0.9367        39
#            ㅡ     0.9500    0.9744    0.9620        39
#            ㅣ     0.9070    0.9750    0.9398        40
#            ㅐ     0.9730    0.9231    0.9474        39
#            ㅒ     0.9512    1.0000    0.9750        39
#            ㅔ     0.9024    0.9737    0.9367        38
#            ㅖ     0.9459    0.8974    0.9211        39
#            ㅚ     0.9737    0.9487    0.9610        39
#            ㅟ     1.0000    0.9744    0.9870        39
#            ㅢ     0.9250    0.9487    0.9367        39
#
#     accuracy                         0.9406      1196
#    macro avg     0.9421    0.9407    0.9405      1196
# weighted avg     0.9423    0.9406    0.9406      1196

# %% [markdown]
# ## 17. ONNX 변환
#
# Jetson에서는 이 ONNX 파일을 이용해 TensorRT `.engine` 파일을 생성합니다.

# %%
# !pip -q install tf2onnx onnx onnxsim
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 839.1/839.1 kB 25.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.1/19.1 MB 59.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 97.4 MB/s eta 0:00:00

# %%
import tf2onnx

ONNX_MODEL_NAME = "Korean_Fingerspelling_MobileNetV2.onnx"

spec = (
    tf.TensorSpec(
        (1, IMG_SIZE, IMG_SIZE, 3),
        tf.float32,
        name="input"
    ),
)

model_proto, _ = tf2onnx.convert.from_keras(
    model_best,
    input_signature=spec,
    opset=18,
    output_path=ONNX_MODEL_NAME
)

print("ONNX 변환 완료:", ONNX_MODEL_NAME)
# Out:
# ONNX 변환 완료: Korean_Fingerspelling_MobileNetV2.onnx

# %% [markdown]
# ## 18. ONNX 단순화

# %%
ONNXSIM_MODEL_NAME = "Korean_Fingerspelling_MobileNetV2.sim.onnx"

# !onnxsim "$ONNX_MODEL_NAME" "$ONNXSIM_MODEL_NAME"
# Out:
# Installing onnxruntime by `/usr/bin/python3 -m pip install onnxruntime`, please
# wait for a moment..
# Collecting onnxruntime
#   Downloading onnxruntime-1.27.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.4 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from onnxruntime) (25.12.19)
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.12/dist-packages (from onnxruntime) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from onnxruntime) (26.2)
# Requirement already satisfied: protobuf>=4.25.8 in /usr/local/lib/python3.12/dist-packages (from onnxruntime) (5.29.6)
# Downloading onnxruntime-1.27.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (18.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.7/18.7 MB 28.4 MB/s eta 0:00:00
# Installing collected packages: onnxruntime
# Successfully installed onnxruntime-1.27.0
# Simplifying...
# Finish! Here is the difference:
# ┏━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┓
# ┃            ┃ Original Model ┃ Simplified Model ┃
# ┡━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━┩
# │ Add        │ 27             │ 27               │
# │ Clip       │ 35             │ 35               │
# │ Constant   │ 131            │ 130              │
# │ Conv       │ 52             │ 52               │
# │ Gemm       │ 2              │ 2                │
# │ Mul        │ 18             │ 18               │
# │ Pad        │ 4              │ 0                │
# │ ReduceMean │ 1              │ 1                │
# │ Relu       │ 1              │ 1                │
# │ Softmax    │ 1              │ 1                │
# │ Sub        │ 1              │ 1                │
# │ Transpose  │ 2              │ 2                │
# │ Model Size │ 9.1MiB         │ 9.1MiB           │
# └────────────┴────────────────┴──────────────────┘

# %% [markdown]
# ## 19. 결과 파일 묶기 및 다운로드

# %%
TARBALL_NAME = "Korean_Fingerspelling_MobileNetV2_Result.tar.gz"

# !tar -zcvf "$TARBALL_NAME"     "$SAVED_MODEL_NAME"     "$ONNX_MODEL_NAME"     "$ONNXSIM_MODEL_NAME"     "$CLASS_NAMES_FILE"

print("생성 완료:", TARBALL_NAME)
# Out:
# Korean_Fingerspelling_MobileNetV2.keras
# Korean_Fingerspelling_MobileNetV2.onnx
# Korean_Fingerspelling_MobileNetV2.sim.onnx
# korean_fingerspelling_class_names.json
# 생성 완료: Korean_Fingerspelling_MobileNetV2_Result.tar.gz

# %%
try:
    from google.colab import files
    files.download(TARBALL_NAME)
except Exception as e:
    print("자동 다운로드는 Colab에서만 지원됩니다.")
    print(e)
